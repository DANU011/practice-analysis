# %% [markdown]
# <a href="https://colab.research.google.com/github/DANU011/practice-analysis/blob/main/coding_practice/1%EC%9C%A0%ED%98%95%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 데이터 - 유트브 데일리 인기동영상 (한국)
url = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0           0                                          [신병] 물자창고
# 1           1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3           3                                       고기남자의 칠면조 파티
# 4           4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
#
#               channelTitle  categoryId  view_count  likes  dislikes  \
# 0                      장삐쭈          23     1893473  38249       730
# 1  RAIN's Official Channel          10     2600864      0         0
# 2              서울시 · Seoul          29      347049   3564       120
# 3             고기남자 MeatMan          26      528458  15372       280
# 4                    스브스밥집          24      494904   3918       111
#
#    comment_count                 channelId trending_date2
# 0           8595  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# ...

# %%
# 인기동영상 제작횟수가 많은 채널 상위 10개명을 출력하라 (날짜기준, 중복포함)
ans =list(df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)]\
             .channelTitle.unique())
print(ans)
'''
df.channelId.value_counts():
df 데이터프레임의 'channelId' 열에 있는 각 고유 값의 빈도를 세는 작업입니다.
.head(10):
빈도가 가장 높은 상위 10개의 값을 선택합니다.
.index:
선택된 상위 10개의 값의 인덱스를 반환합니다.
df.channelId.isin(...):
'channelId' 열의 각 값이 이전 단계에서 선택된 상위 10개의 값 중 하나에 속하는지 여부를 나타내는 불리언 시리즈를 생성합니다.
df.loc[...]:
이전 단계에서 생성된 불리언 시리즈를 사용하여 원본 데이터프레임에서 조건에 해당하는 행만 선택합니다.
.channelTitle.unique():
선택된 행들 중에서 'channelTitle' 열의 고유한 값들을 추출합니다.
list(...):
최종적으로 얻은 고유한 'channelTitle' 값을 리스트로 변환합니다.
''';
# Out:
# ['장삐쭈', '총몇명', '파뿌리', '짤툰', '런닝맨 - 스브스 공식 채널', '엠뚜루마뚜루 : MBC 공식 종합 채널', 'SPOTV', '채널 십오야', '이과장', 'BANGTANTV']

# %%
# 논란으로 인기동영상이 된 케이스를 확인하고 싶다. dislikes수가 like 수보다 높은 동영상을 제작한 채널을 모두 출력하라
ans = list(df.loc[df.likes < df.dislikes].channelTitle.unique())
print(ans)
# Out:
# ['핫도그TV', 'ASMR 애정TV', '하얀트리HayanTree', '양팡 YangPang', '철구형 (CHULTUBE)', '왜냐맨하우스', '(MUTUBE)와꾸대장봉준', '오메킴TV', '육지담', 'MapleStory_KR', 'ROAD FIGHTING CHAMPIONSHIP', '사나이 김기훈', '나혼자산다 STUDIO', 'Gen.G esports']

# %%
# 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이므로 이를 통해 채널명을 한번이라도 바꾼 채널의 갯수를 구하여라
change = df[['channelTitle', 'channelId']].drop_duplicates().channelId.value_counts()
target = change[change > 1]
print(len(target))

'''
df[['channelTitle', 'channelId']]:
'channelTitle'과 'channelId' 열만 선택하여 새로운 데이터프레임을 만듭니다.
.drop_duplicates():
중복된 행을 제거합니다. 여기서는 'channelId'를 기준으로 중복을 제거합니다.
.channelId.value_counts():
'channelId' 열의 각 고유 값의 빈도를 세는 작업을 수행합니다.
change[change > 1]:
빈도가 1보다 큰 경우, 즉 중복된 'channelId'가 있는 경우만 선택합니다.
len(target):
선택된 중복된 'channelId'의 개수를 계산합니다.
print(len(target)):
최종적으로 중복된 'channelId' 중에서 'channelTitle'이 한 번 이상 변경된 경우의 개수를 출력합니다.
''';
# Out:
# 71

# %%
# 일요일에 인기있었던 영상들중 가장많은 영상 종류(categoryId)는 무엇인가?
df['trending_date2'] = pd.to_datetime(df['trending_date2'])
ans = df.loc[df['trending_date2'].dt.day_name() == 'Sunday'].categoryId.value_counts().index[0]
print(ans)

'''
df['trending_date2'] = pd.to_datetime(df['trending_date2']):
'trending_date2' 열의 값을 날짜 형식으로 변환합니다.
df.loc[df['trending_date2'].dt.day_name() == 'Sunday']:
'trending_date2' 열의 날짜를 기준으로 일요일에 해당하는 행들만 선택합니다.
.categoryID.value_counts().index[0]:
선택된 행들 중에서 'categoryId' 열의 각 고유 값의 빈도를 세고, 그 중 가장 많이 나타난 값의 인덱스를 선택합니다.
''';
# Out:
# 24

# %%
# 각 요일별 인기 영상들의 categoryId는 각각 몇개 씩인지 하나의 데이터 프레임으로 표현하라
group = df.groupby([df['trending_date2'].dt.day_name(), 'categoryId'], as_index = False).size()
ans = group.pivot(index = 'categoryId', columns = 'trending_date2')
display(ans)
'''
df.groupby([df['trending_date2'].dt.day_name(), 'categoryId'], as_index=False).size():
'trending_date2'의 날짜를 기준으로 해당 요일과 'categoryId'를 기준으로 그룹화합니다.
as_index=False는 그룹화된 열을 인덱스로 사용하지 않도록 설정합니다.
size() 함수는 각 그룹의 크기를 계산합니다.
group.pivot(index='categoryId', columns='trending_date2'):
pivot 함수를 사용하여 그룹화된 데이터를 피벗 테이블로 변환합니다.
'categoryId'를 인덱스로, 'trending_date2'를 열로, 그룹의 크기를 값으로 사용합니다.
display(ans):
최종적으로 피벗 테이블을 출력합니다.
''';
# Out:
#                  size
# trending_date2 Friday Monday Saturday Sunday Thursday Tuesday Wednesday
# categoryId
# 1                 243    263      255    274      246     257       234
# 2                 120    105      119     99      128     119       129
# 10                833    837      776    830      890     894       917
# 15                187    215      198    217      207     208       207
# 17                633    668      592    636      682     708       706
# 19                 90     92       87     91       92      89        85
# 20                283    298      296    289      282     285       291
# 22               1288   1373     1289   1337     1341    1375      1333
# 23                568    594      570    556      560     569       566
# 24               2976   3148     3066   3096     2954    3084      3090
# 25                444    453      422    437      470     452       468
# 26                369    378      364    363      375     394       385
# ...

# %%
# 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다. viewcount대비 댓글수가 가장 높은 영상을 확인하라 (view_count값이 0인 경우는 제외한다)
target2 = df.loc[df.view_count != 0]
t = target2.copy()
t['ratio'] = (target2['comment_count']/target2['view_count']).dropna()
ans = t.sort_values(by = 'ratio', ascending = False).iloc[0].title
print(ans)
'''
target2 = df.loc[df.view_count != 0]:
'view_count' 값이 0인 경우를 제외하고, 나머지 데이터를 선택합니다.
t = target2.copy():
선택된 데이터프레임의 복사본을 만듭니다.
t['ratio'] = (target2['comment_count'] / target2['view_count']).dropna():
댓글 수 대비 조회 수 비율(ratio) 열을 추가합니다. dropna()는 NaN(결측치) 값을 제거합니다.
t.sort_values(by='ratio', ascending=False).iloc[0].title:
비율(ratio)에 따라 내림차순으로 데이터프레임을 정렬하고, 가장 높은 비율을 가진 영상의 제목을 선택합니다.
''';
# Out:
# 60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)

# %%
# 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다.viewcount대비 댓글수가 가장 낮은 영상을 확인하라 (view_counts, ratio값이 0인경우는 제외한다.)
ratio = (df['comment_count'] / df['view_count']).dropna().sort_values()

ans = df.iloc[ratio[ratio != 0].index[0]].title
print(ans)
# Out:
# Join the BTS #PermissiontoDance Challenge only on YouTube #Shorts

# %%
# like 대비 dislike의 수가 가장 적은 영상은 무엇인가? (like, dislike 값이 0인경우는 제외한다)
target = df.loc[(df.likes !=0) & (df.dislikes !=0)]
ratio = (target['dislikes'] / target['likes']).sort_values().index[0]

ans = df.iloc[ratio].title
print(ans)
# Out:
# [줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가득한 NCT 127 도영&정우의 줌터뷰

# %%
# 가장많은 트렌드 영상을 제작한 채널의 이름은 무엇인가? (날짜기준, 중복포함)
ans = df.loc[df.channelId == df.channelId.value_counts().index[0]].channelTitle.unique()[0]
print(ans)
# Out:
# 짤툰

# %%
# 20회(20일)이상 인기동영상 리스트에 포함된 동영상의 숫자는?
ans = (df[['title', 'channelId']].value_counts() >= 20).sum()
print(ans)
# Out:
# 40

# %%
# 데이터 출처 :https://www.kaggle.com/kukuroo3/youtube-episodic-contents-kr(참고, 데이터 수정)
# 데이터 설명 : 유튜브 “공범” 컨텐츠 동영상 정보 ( 10분 간격 수집)
dataurl_video = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/videoInfo.csv'
dataurl_channel = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/channelInfo.csv'

import pandas as pd

channel = pd.read_csv(dataurl_channel)
video = pd.read_csv(dataurl_video)

display(channel.head())
display(video.head())
# Out:
#                   channelid   subcnt    viewcnt  videocnt  \
# 0  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  410238653       736
# 1  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       736
# 2  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       735
# 3  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       737
# 4  UCkQCwnkQfgSuPTTnw_Y7v7w  1320000  412531322       737
#
#                     ct channelname
# 0  2021-09-30 03:01:03         꽈뚜룹
# 1  2021-09-30 09:01:03         꽈뚜룹
# 2  2021-09-30 15:01:03         꽈뚜룹
# 3  2021-09-30 21:01:03         꽈뚜룹
# 4  2021-10-01 03:01:04         꽈뚜룹
#        videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 0  c5JQp6xafqc  1667010    30474         706            0   6587
# 1  c5JQp6xafqc  1669089    30495         707            0   6589
# 2  c5JQp6xafqc  1674759    30522         711            0   6596
# 3  c5JQp6xafqc  1677026    30555         712            0   6604
# 4  c5JQp6xafqc  1681824    30585         713            0   6600
#
# ...

# %%
# 각 데이터의 ‘ct’컬럼을 시간으로 인식할수 있게 datatype을 변경하고 video 데이터의 videoname의 각 value 마다 몇개의 데이터씩 가지고 있는지 확인하라
video['ct'] = pd.to_datetime(video['ct'])
ans = video.videoname.value_counts()
print(ans)
# Out:
#  공범 EP1    3492
#  공범 EP2    3204
#  공범 EP3    2568
#  공범 EP4    2280
#  공범 EP5    1562
#  공범 EP6    1274
#  공범 EP7     555
#  공범 EP8     266
# Name: videoname, dtype: int64

# %%
# 수집된 각 video의 가장 최신화 된 날짜의 viewcount값을 출력하라
ans = video.sort_values(['videoname','ct']).drop_duplicates('videoname',keep='last')[['viewcnt','videoname','ct']].reset_index(drop=True)
display(ans)
# Out:
#    viewcnt videoname                  ct
# 0  3180532    공범 EP1 2021-11-01 15:30:03
# 1  2199328    공범 EP2 2021-11-01 15:30:03
# 2  1671294    공범 EP3 2021-11-01 15:30:03
# 3  1818493    공범 EP4 2021-11-01 15:30:03
# 4  1503435    공범 EP5 2021-11-01 15:30:04
# 5  1750222    공범 EP6 2021-11-01 15:30:04
# 6  1630200    공범 EP7 2021-11-01 15:30:05
# 7  1289088    공범 EP8 2021-11-01 15:30:05

# %%
# Channel 데이터중 2021-10-03일 이후 각 채널의 처음 기록 됐던 구독자 수(subcnt)를 출력하라
channel.ct = pd.to_datetime(channel.ct)
target = channel[channel.ct >= pd.to_datetime('2021-10-03')].sort_values(['ct', 'channelname']).drop_duplicates('channelname')
ans = target[['channelname', 'subcnt']].reset_index(drop = True)
print(ans)
# Out:
#         channelname   subcnt
# 0            논리왕 전기   922000
# 1             야전삽짱재   257000
# 2        츄정ChuJeong   322000
# 3        김농밀의 농밀한 삶     7520
# 4       릴펄 Lilpearl    10100
# 5   와글와글 WagleWagle    55000
# 6               조나단   215000
# 7           형사!탐정되다    14900
# 8     Balming Tiger    54300
# 9     곽토리 kwak tori   471000
# 10              꽈뚜룹  1330000

# %%
# 각채널의 2021-10-03 03:00:00 ~ 2021-11-01 15:00:00 까지 구독자수 (subcnt) 의 증가량을 구하여라
end = channel.loc[channel.ct.dt.strftime('%Y-%m-%d %H') =='2021-11-01 15']
start = channel.loc[channel.ct.dt.strftime('%Y-%m-%d %H') =='2021-10-03 03']

end_df = end[['channelname','subcnt']].reset_index(drop=True)
start_df = start[['channelname','subcnt']].reset_index(drop=True)

end_df.columns = ['channelname','end_sub']
start_df.columns = ['channelname','start_sub']


tt = pd.merge(start_df,end_df)
tt['del'] = tt['end_sub'] - tt['start_sub']
result = tt[['channelname','del']]
display(result)
# Out:
#         channelname    del
# 0               꽈뚜룹  70000
# 1             야전삽짱재  11000
# 2        츄정ChuJeong   1000
# 3            논리왕 전기 -11000
# 4   와글와글 WagleWagle      0
# 5               조나단  12000
# 6           형사!탐정되다  10300
# 7        김농밀의 농밀한 삶   1540
# 8       릴펄 Lilpearl  11000
# 9     곽토리 kwak tori  -2000
# 10    Balming Tiger   2500
